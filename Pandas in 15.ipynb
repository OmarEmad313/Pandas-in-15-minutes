# %% [markdown]
# # Pandas in 15 minutes

# %%
import pandas as pd

# %%
df = pd.read_csv('top 100 streamed songs.csv')

# %%
df.head()
# Out:
#                        id                                               name  \
# 0  4ZtFanR9U6ndgddUvNcjcG                            Good 4 U Olivia Rodrigo
# 1  5fxyZf6m2xHeSrOzUfcJrq                 Stay The Kid LAROI & Justin Bieber
# 2  5nujrmhLynf4yMoMtj8AQF                   Levitating Dua Lipa feat. DaBaby
# 3  4iJyoBOLtHqaGxP12qzhQI  Peaches Justin Bieber feat. Daniel Caesar & Gi...
# 4  1SC5rEoYDGUK4NfG82494W           Montero (Call Me By Your Name) Lil Nas X
#
#    duration  energy  key  loudness  mode  speechiness  acousticness  \
# 0      2.97   0.664    9    -5.044     1       0.1540       0.33500
# 1      2.30   0.506    8   -11.275     1       0.0589       0.37900
# 2      3.38   0.825    6    -3.787     0       0.0601       0.00883
# 3      3.30   0.696    0    -6.181     1       0.1190       0.32100
# 4      2.30   0.503    8    -6.725     0       0.2200       0.29300
#
#    instrumentalness  liveness  valence    tempo  danceability
# ...

# %%
df.tail()
# Out:
#                         id                                               name  \
# 95  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon) Justin ...
# 96  1FSWSs9CL01RCYxXtm08Rf                    Dance With Me Tonight Olly Murs
# 97  54bFM56PmE4YLRnqpW6Tha                       Therefore I Am Billie Eilish
# 98  5jsw9uXEGuKyJzs0boZ1bT                              Stitches Shawn Mendes
# 99  1SC5rEoYDGUK4NfG82494W           Montero (Call Me By Your Name) Lil Nas X
#
#     duration  energy  key  loudness  mode  speechiness  acousticness  \
# 95      3.30   0.696    0    -6.181     1       0.1190        0.3210
# 96      3.37   0.748   11    -5.922     0       0.0589        0.3050
# 97      2.91   0.340   11    -7.773     0       0.0697        0.2180
# 98      3.45   0.754    1    -6.684     1       0.0615        0.0151
# 99      2.30   0.503    8    -6.725     0       0.2200        0.2930
#
#     instrumentalness  liveness  valence    tempo  danceability
# ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'duration', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'danceability'],
#       dtype='object')

# %%
df.dtypes
# Out:
# id                   object
# name                 object
# duration            float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# danceability        float64
# dtype: object

# %%
df.describe()
# Out:
#          duration      energy        key    loudness        mode  speechiness  \
# count  100.000000  100.000000  100.00000  100.000000  100.000000   100.000000
# mean     3.404900    0.587650    5.05000   -6.577120    0.560000     0.075461
# std      0.927022    0.168273    3.82542    2.447338    0.498888     0.068065
# min      0.730000    0.157000    0.00000  -14.067000    0.000000     0.025300
# 25%      2.910000    0.477750    1.00000   -7.676250    0.000000     0.036100
# 50%      3.370000    0.609000    5.00000   -6.262500    1.000000     0.051800
# 75%      3.630000    0.707750    8.00000   -4.786750    1.000000     0.080650
# max     10.220000    0.883000   11.00000   -2.724000    1.000000     0.368000
#
#        acousticness  instrumentalness    liveness     valence       tempo  \
# count    100.000000        100.000000  100.000000  100.000000  100.000000
# mean       0.314539          0.070682    0.161737    0.517354  121.548260
# ...

# %%
df.describe(include="object")
# Out:
#                             id                          name
# count                      100                           100
# unique                      86                            90
# top     5nujrmhLynf4yMoMtj8AQF  Therefore I Am Billie Eilish
# freq                         3                             3

# %%
df["name"]
# Out:
# 0                               Good 4 U Olivia Rodrigo
# 1                    Stay The Kid LAROI & Justin Bieber
# 2                      Levitating Dua Lipa feat. DaBaby
# 3     Peaches Justin Bieber feat. Daniel Caesar & Gi...
# 4              Montero (Call Me By Your Name) Lil Nas X
#                             ...
# 95    Peaches (feat. Daniel Caesar & Giveon) Justin ...
# 96                      Dance With Me Tonight Olly Murs
# 97                         Therefore I Am Billie Eilish
# 98                                Stitches Shawn Mendes
# 99             Montero (Call Me By Your Name) Lil Nas X
# Name: name, Length: 100, dtype: object

# %%
df.name
# Out:
# 0                               Good 4 U Olivia Rodrigo
# 1                    Stay The Kid LAROI & Justin Bieber
# 2                      Levitating Dua Lipa feat. DaBaby
# 3     Peaches Justin Bieber feat. Daniel Caesar & Gi...
# 4              Montero (Call Me By Your Name) Lil Nas X
#                             ...
# 95    Peaches (feat. Daniel Caesar & Giveon) Justin ...
# 96                      Dance With Me Tonight Olly Murs
# 97                         Therefore I Am Billie Eilish
# 98                                Stitches Shawn Mendes
# 99             Montero (Call Me By Your Name) Lil Nas X
# Name: name, Length: 100, dtype: object

# %%
df[["id","name"]]
# Out:
#                         id                                               name
# 0   4ZtFanR9U6ndgddUvNcjcG                            Good 4 U Olivia Rodrigo
# 1   5fxyZf6m2xHeSrOzUfcJrq                 Stay The Kid LAROI & Justin Bieber
# 2   5nujrmhLynf4yMoMtj8AQF                   Levitating Dua Lipa feat. DaBaby
# 3   4iJyoBOLtHqaGxP12qzhQI  Peaches Justin Bieber feat. Daniel Caesar & Gi...
# 4   1SC5rEoYDGUK4NfG82494W           Montero (Call Me By Your Name) Lil Nas X
# ..                     ...                                                ...
# 95  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon) Justin ...
# 96  1FSWSs9CL01RCYxXtm08Rf                    Dance With Me Tonight Olly Murs
# 97  54bFM56PmE4YLRnqpW6Tha                       Therefore I Am Billie Eilish
# 98  5jsw9uXEGuKyJzs0boZ1bT                              Stitches Shawn Mendes
# 99  1SC5rEoYDGUK4NfG82494W           Montero (Call Me By Your Name) Lil Nas X
#
# [100 rows x 2 columns]

# %%
df.name.unique()
# Out:
# array(['Good 4 U Olivia Rodrigo', 'Stay The Kid LAROI & Justin Bieber',
#        'Levitating Dua Lipa feat. DaBaby',
#        'Peaches Justin Bieber feat. Daniel Caesar & Giveon',
#        'Montero (Call Me By Your Name) Lil Nas X',
#        'Kiss Me More (feat. SZA) Doja Cat',
#        'Leave The Door Open Silk Sonic (Bruno Mars & Anderson .Paak)',
#        'drivers license Olivia Rodrigo', 'Blinding Lights The Weeknd',
#        'Deja Vu Olivia Rodrigo', 'The Business Tiësto',
#        'Astronaut In The Ocean Masked Wolf', 'Rapstar Polo G',
#        'Beautiful Mistakes (feat. Megan Thee Stallion) Maroon 5',
#        'Heartbreak Anniversary Giveon', 'Heat Waves Glass Animals',
#        'Without You (with Miley Cyrus) The Kid LAROI & Miley Cyrus',
#        'Mood (feat. iann dior) 24kGoldn',
#        'Fiel Los Legendarios, Wisin & Jhay Cortez',
#        'Watermelon Sugar Harry Styles', 'Arcade Duncan Laurence',
#        'Mood Swings (feat. Lil Tjay) Pop Smoke',
# ...

# %%
df[df['duration']>3.00]
# Out:
#                         id                                               name  \
# 2   5nujrmhLynf4yMoMtj8AQF                   Levitating Dua Lipa feat. DaBaby
# 3   4iJyoBOLtHqaGxP12qzhQI  Peaches Justin Bieber feat. Daniel Caesar & Gi...
# 5   3DarAbFujv6eYNliUTyqtz                  Kiss Me More (feat. SZA) Doja Cat
# 6   02VBYrHfVwfEWXk5DXyf0T  Leave The Door Open Silk Sonic (Bruno Mars & A...
# 7   5wANPM4fQCJwkGd4rN57mH                     drivers license Olivia Rodrigo
# ..                     ...                                                ...
# 93  2JPLbjOn0wPCngEot2STUS                                 Yonaguni Bad Bunny
# 94  7oD0hfEoijJtSXj7fblDor    Levitating - The Blessed Madonna Remix Dua Lipa
# 95  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon) Justin ...
# 96  1FSWSs9CL01RCYxXtm08Rf                    Dance With Me Tonight Olly Murs
# 98  5jsw9uXEGuKyJzs0boZ1bT                              Stitches Shawn Mendes
#
# ...

# %%
df.iloc[2]
# Out:
# id                            5nujrmhLynf4yMoMtj8AQF
# name                Levitating Dua Lipa feat. DaBaby
# duration                                        3.38
# energy                                         0.825
# key                                                6
# loudness                                      -3.787
# mode                                               0
# speechiness                                   0.0601
# acousticness                                 0.00883
# instrumentalness                                 0.0
# liveness                                      0.0674
# valence                                        0.915
# tempo                                        102.977
# danceability                                   0.702
# Name: 2, dtype: object

# %%
df.iloc[0:3]
# Out:
#                        id                                name  duration  \
# 0  4ZtFanR9U6ndgddUvNcjcG             Good 4 U Olivia Rodrigo      2.97
# 1  5fxyZf6m2xHeSrOzUfcJrq  Stay The Kid LAROI & Justin Bieber      2.30
# 2  5nujrmhLynf4yMoMtj8AQF    Levitating Dua Lipa feat. DaBaby      3.38
#
#    energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.664    9    -5.044     1       0.1540       0.33500             0.000
# 1   0.506    8   -11.275     1       0.0589       0.37900             0.868
# 2   0.825    6    -3.787     0       0.0601       0.00883             0.000
#
#    liveness  valence    tempo  danceability
# 0    0.0849    0.688  166.928         0.563
# 1    0.1100    0.454  170.054         0.564
# 2    0.0674    0.915  102.977         0.702

# %%
df.iloc[3,3]
# Out:
# 0.696

# %%
df2 =df.copy()

# %%
df2
# Out:
#                         id                                               name  \
# 0   4ZtFanR9U6ndgddUvNcjcG                            Good 4 U Olivia Rodrigo
# 1   5fxyZf6m2xHeSrOzUfcJrq                 Stay The Kid LAROI & Justin Bieber
# 2   5nujrmhLynf4yMoMtj8AQF                   Levitating Dua Lipa feat. DaBaby
# 3   4iJyoBOLtHqaGxP12qzhQI  Peaches Justin Bieber feat. Daniel Caesar & Gi...
# 4   1SC5rEoYDGUK4NfG82494W           Montero (Call Me By Your Name) Lil Nas X
# ..                     ...                                                ...
# 95  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon) Justin ...
# 96  1FSWSs9CL01RCYxXtm08Rf                    Dance With Me Tonight Olly Murs
# 97  54bFM56PmE4YLRnqpW6Tha                       Therefore I Am Billie Eilish
# 98  5jsw9uXEGuKyJzs0boZ1bT                              Stitches Shawn Mendes
# 99  1SC5rEoYDGUK4NfG82494W           Montero (Call Me By Your Name) Lil Nas X
#
# ...

# %%
df2.set_index('name',inplace=True)

# %%
df2
# Out:
#                                                                         id  \
# name
# Good 4 U Olivia Rodrigo                             4ZtFanR9U6ndgddUvNcjcG
# Stay The Kid LAROI & Justin Bieber                  5fxyZf6m2xHeSrOzUfcJrq
# Levitating Dua Lipa feat. DaBaby                    5nujrmhLynf4yMoMtj8AQF
# Peaches Justin Bieber feat. Daniel Caesar & Giveon  4iJyoBOLtHqaGxP12qzhQI
# Montero (Call Me By Your Name) Lil Nas X            1SC5rEoYDGUK4NfG82494W
# ...                                                                    ...
# Peaches (feat. Daniel Caesar & Giveon) Justin B...  4iJyoBOLtHqaGxP12qzhQI
# Dance With Me Tonight Olly Murs                     1FSWSs9CL01RCYxXtm08Rf
# Therefore I Am Billie Eilish                        54bFM56PmE4YLRnqpW6Tha
# Stitches Shawn Mendes                               5jsw9uXEGuKyJzs0boZ1bT
# Montero (Call Me By Your Name) Lil Nas X            1SC5rEoYDGUK4NfG82494W
#
# ...

# %%
df2.loc['Stitches Shawn Mendes']
# Out:
# id                  5jsw9uXEGuKyJzs0boZ1bT
# duration                              3.45
# energy                               0.754
# key                                      1
# loudness                            -6.684
# mode                                     1
# speechiness                         0.0615
# acousticness                        0.0151
# instrumentalness                       0.0
# liveness                            0.0486
# valence                              0.755
# tempo                              149.789
# danceability                         0.752
# Name: Stitches Shawn Mendes, dtype: object

# %%
df.drop('tempo',axis=1)
# Out:
#                         id                                               name  \
# 0   4ZtFanR9U6ndgddUvNcjcG                            Good 4 U Olivia Rodrigo
# 1   5fxyZf6m2xHeSrOzUfcJrq                 Stay The Kid LAROI & Justin Bieber
# 2   5nujrmhLynf4yMoMtj8AQF                   Levitating Dua Lipa feat. DaBaby
# 3   4iJyoBOLtHqaGxP12qzhQI  Peaches Justin Bieber feat. Daniel Caesar & Gi...
# 4   1SC5rEoYDGUK4NfG82494W           Montero (Call Me By Your Name) Lil Nas X
# ..                     ...                                                ...
# 95  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon) Justin ...
# 96  1FSWSs9CL01RCYxXtm08Rf                    Dance With Me Tonight Olly Murs
# 97  54bFM56PmE4YLRnqpW6Tha                       Therefore I Am Billie Eilish
# 98  5jsw9uXEGuKyJzs0boZ1bT                              Stitches Shawn Mendes
# 99  1SC5rEoYDGUK4NfG82494W           Montero (Call Me By Your Name) Lil Nas X
#
# ...

# %%
df["subscribe"]="subscribe"

# %%
len(df.columns)
# Out:
# 15

# %%
df.iloc[1,14]="like"

# %%
df
# Out:
#                         id                                               name  \
# 0   4ZtFanR9U6ndgddUvNcjcG                            Good 4 U Olivia Rodrigo
# 1   5fxyZf6m2xHeSrOzUfcJrq                 Stay The Kid LAROI & Justin Bieber
# 2   5nujrmhLynf4yMoMtj8AQF                   Levitating Dua Lipa feat. DaBaby
# 3   4iJyoBOLtHqaGxP12qzhQI  Peaches Justin Bieber feat. Daniel Caesar & Gi...
# 4   1SC5rEoYDGUK4NfG82494W           Montero (Call Me By Your Name) Lil Nas X
# ..                     ...                                                ...
# 95  4iJyoBOLtHqaGxP12qzhQI  Peaches (feat. Daniel Caesar & Giveon) Justin ...
# 96  1FSWSs9CL01RCYxXtm08Rf                    Dance With Me Tonight Olly Murs
# 97  54bFM56PmE4YLRnqpW6Tha                       Therefore I Am Billie Eilish
# 98  5jsw9uXEGuKyJzs0boZ1bT                              Stitches Shawn Mendes
# 99  1SC5rEoYDGUK4NfG82494W           Montero (Call Me By Your Name) Lil Nas X
#
# ...
